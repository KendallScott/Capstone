# %% [markdown]
# <a href="https://colab.research.google.com/github/taddbackus/capstone/blob/main/Copy_of_Compiled_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geemap==0.6.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geemap==0.6.4
#   Downloading geemap-0.6.4-py2.py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.9 MB/s eta 0:00:00
# Collecting bqplot (from geemap==0.6.4)
#   Downloading bqplot-0.12.39-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geemap==0.6.4) (8.1.3)
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.10/dist-packages (from geemap==0.6.4) (0.1.350)
# Requirement already satisfied: folium>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from geemap==0.6.4) (0.14.0)
# Collecting ipyleaflet>=0.12.2 (from geemap==0.6.4)
#   Downloading ipyleaflet-0.17.3-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 58.4 MB/s eta 0:00:00
# Collecting ipynb-py-convert (from geemap==0.6.4)
#   Downloading ipynb-py-convert-0.4.6.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyshp (from geemap==0.6.4)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium>=0.10.1->geemap==0.6.4) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium>=0.10.1->geemap==0.6.4) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium>=0.10.1->geemap==0.6.4) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium>=0.10.1->geemap==0.6.4) (2.27.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet>=0.12.2->geemap==0.6.4) (7.7.1)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.12.2->geemap==0.6.4)
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting xyzservices>=2021.8.1 (from ipyleaflet>=0.12.2->geemap==0.6.4)
#   Downloading xyzservices-2023.5.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from bqplot->geemap==0.6.4) (5.7.1)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bqplot->geemap==0.6.4) (1.5.3)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from earthengine-api->geemap==0.6.4) (2.8.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->geemap==0.6.4) (2.84.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->geemap==0.6.4) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->geemap==0.6.4) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->geemap==0.6.4) (0.21.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api->geemap==0.6.4) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api->geemap==0.6.4) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->geemap==0.6.4) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->geemap==0.6.4) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->geemap==0.6.4) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->geemap==0.6.4) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.9.2->earthengine-api->geemap==0.6.4) (3.0.9)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (3.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium>=0.10.1->geemap==0.6.4) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.0.0->bqplot->geemap==0.6.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.0.0->bqplot->geemap==0.6.4) (2022.7.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api->geemap==0.6.4) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api->geemap==0.6.4) (2.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium>=0.10.1->geemap==0.6.4) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium>=0.10.1->geemap==0.6.4) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium>=0.10.1->geemap==0.6.4) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium>=0.10.1->geemap==0.6.4) (3.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->geemap==0.6.4) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->geemap==0.6.4) (3.20.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api->geemap==0.6.4) (1.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (6.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (4.8.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->geemap==0.6.4) (0.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.8.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.7.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.12.2->geemap==0.6.4) (2.21)
# Building wheels for collected packages: ipynb-py-convert
#   Building wheel for ipynb-py-convert (setup.py) ... done
#   Created wheel for ipynb-py-convert: filename=ipynb_py_convert-0.4.6-py3-none-any.whl size=4623 sha256=3994d9c73994588940b9f879f206eff5b5a984f4f4daada6717b05937ace2c14
#   Stored in directory: /root/.cache/pip/wheels/69/a2/b7/2816fda86a647adbe8c4e7b7f4cc72cdc37720ad11b1611af5
# Successfully built ipynb-py-convert
# Installing collected packages: ipynb-py-convert, xyzservices, traittypes, pyshp, jedi, ipyleaflet, bqplot, geemap
# Successfully installed bqplot-0.12.39 geemap-0.6.4 ipyleaflet-0.17.3 ipynb-py-convert-0.4.6 jedi-0.18.2 pyshp-2.3.1 traittypes-0.2.1 xyzservices-2023.5.0

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.13.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.1 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas)
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 68.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.0.1 (from geopandas)
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 69.9 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Installing collected packages: pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.0 pyproj-3.5.0

# %%
import ee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=P3qOXv6drKUAMrxhu1iYfmXeW2cfKiHwAZt4sbGSIsw&tc=BtOKEo3k3LHycBFPWTps9mRjUC24XUqRQqHh64GkTU8&cc=dBWoZyaFsvUBo-3MRq-bfFBXmwsmoY2rZhS5M3bFVAg
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AbUR2VOeaulai8PPtdZEAfGmXxu0Mqo6T8UV3lmXAtruwXzqil2BcjYvHFA
#
# Successfully saved authorization token.

# %%
#demo of google earth API

# Import the MODIS land cover collection.
lc = ee.ImageCollection('MODIS/006/MCD12Q1')

# Import the MODIS land surface temperature collection.
lst = ee.ImageCollection('MODIS/006/MOD11A1')

# Import the USGS ground elevation image.
elv = ee.Image('USGS/SRTMGL1_003')

i_date = '2017-01-01'

# Final date of interest (exclusive).
f_date = '2020-01-01'

# Selection of appropriate bands and dates for LST.
lst = lst.select('LST_Day_1km', 'QC_Day').filterDate(i_date, f_date)

# Define the urban location of interest as a point near Lyon, France.
u_lon = 4.8148
u_lat = 45.7758
u_poi = ee.Geometry.Point(u_lon, u_lat)

# Define the rural location of interest as a point away from the city.
r_lon = 5.175964
r_lat = 45.574064
r_poi = ee.Geometry.Point(r_lon, r_lat)

scale = 1000  # scale in meters

# Print the elevation near Lyon, France.
elv_urban_point = elv.sample(u_poi, scale).first().get('elevation').getInfo()
print('Ground elevation at urban point:', elv_urban_point, 'm')

# Calculate and print the mean value of the LST collection at the point.
lst_urban_point = lst.mean().sample(u_poi, scale).first().get('LST_Day_1km').getInfo()
print('Average daytime LST at urban point:', round(lst_urban_point*0.02 -273.15, 2), '°C')

# Print the land cover type at the point.
lc_urban_point = lc.first().sample(u_poi, scale).first().get('LC_Type1').getInfo()
print('Land cover value at urban point is:', lc_urban_point)
# Out:
# Ground elevation at urban point: 196 m
# Average daytime LST at urban point: 23.12 °C
# Land cover value at urban point is: 13

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import label_binarize, OneHotEncoder

# %%
import geopandas as gpd
ky_mines = gpd.read_file('/content/KY_Released_mines.geojson')
tn_mines = gpd.read_file('/content/TN_Released_mines.geojson')
va_mines = gpd.read_file('/content/VA_Released_mines.geojson')
wv_mines = gpd.read_file('/content/WV_Released_mines.geojson')

# %%
ky_mines
# Out:
#                          id  ACT_INAC  Calc_Acres  \
# 0      00000000000000001111  Released  294.302954
# 1      00000000000000001112  Released  305.739886
# 2      00000000000000001f4d  Released    4.822285
# 3      00000000000000002b96  Released    6.335894
# 4      00000000000000001d20  Released    2.864151
# ...                     ...       ...         ...
# 12601  0000000000000000025a  Released    1.112072
# 12602  00000000000000002e38  Released    4.185860
# 12603  00000000000000000472  Released   56.660359
# 12604  0000000000000000308a  Released   14.972560
# 12605  000000000000000004fc  Released   35.631015
#
#                            Contact       DATE_ISS FeatCLS MINE_STATU  \
# 0      KY Division of Mine Permits  1141718400000      SF         FF
# 1      KY Division of Mine Permits  1141718400000      SF         FF
# 2      KY Division of Mine Permits   374486400000      SF         FF
# 3      KY Division of Mine Permits   322732800000      SF         FF
# 4      KY Division of Mine Permits   455871600000      SF         FF
# ...                            ...            ...     ...        ...
# 12601  KY Division of Mine Permits   225619200000      SF         XX
# 12602  KY Division of Mine Permits   278582400000      SF         XX
# 12603  KY Division of Mine Permits   255254400000      SF         XX
# 12604  KY Division of Mine Permits   166863600000      SF         XX
# 12605  KY Division of Mine Permits   262598400000      SF         XX
#
#       National_I ORIG_PERM                                           PERM_ACT  \
# 0      KY8640180   8640180  SU      03/07/2013  AM   1  05/12/2011  RN   1...
# 1      KY8640180   8640180  SU      03/07/2013  AM   1  05/12/2011  RN   1...
# 2      KY0130119   0130119                                 NW      11/13/1981
# 3      KY1005000   1005000             RV      01/13/1981  NW      03/24/1980
# 4      KY9180010   9180010                                 NW      06/12/1984
# ...          ...       ...                                                ...
# 12601  KY545876X   545876X                                 NW      02/24/1977
# 12602  KY2660005   2660005                                 NW      10/30/1978
# 12603  KY686977X   686977X                                 NW      02/02/1978
# 12604  KY388574X   388574X             AM      07/14/1975  NW      04/16/1975
# 12605  KY710477X   710477X                                 NW      04/28/1978
#
#                             PER_NAME   PER_TYPE PermitNo       QUAD_DESC  \
# 0                   B & C ENERGY INC  PERMANENT  8640180           MAZIE
# 1                   B & C ENERGY INC  PERMANENT  8640180           MAZIE
# 2      TENKILLER MINING SERVICES INC    INTERIM  0130119
# 3               LAUREL RIVER COAL CO    INTERIM  1005000             ANO
# 4                 RIDNER COAL CO INC  PERMANENT  9180010             VOX
# ...                              ...        ...      ...             ...
# 12601             B J & C COAL SALES    PRE LAW  545876X         MILLARD
# 12602             FALCON COAL CO INC    INTERIM  2660005      HYDEN EAST
# 12603               CAL GLO COAL INC    PRE LAW  686977X    BARBOURVILLE
# 12604         KY PACIFIC MINING CORP    PRE LAW  388574X    BARBOURVILLE
# 12605        T & T DARBY COAL CO INC    PRE LAW  710477X  PENNINGTON GAP
#
#          REGION_DES    Shape_Leng       Source Type_Flag  \
# 0      PRESTONSBURG  53267.493940         CHIA      TRNS
# 1      PRESTONSBURG  92560.008796        KYDMP      TRNS
# 2            LONDON   1820.653854  KGS Project     INACT
# 3            LONDON   3259.238489  KGS Project     INACT
# 4       MIDDLESBORO   1867.456008  KGS Project     INACT
# ...             ...           ...          ...       ...
# 12601     PIKEVILLE   2501.756117  KGS Project     INACT
# 12602        LONDON   1713.922701  KGS Project     INACT
# 12603   MIDDLESBORO  16743.038634  KGS Project     INACT
# 12604   MIDDLESBORO   7858.160818  KGS Project     INACT
# 12605   MIDDLESBORO  77683.903613  KGS Project     INACT
#
#                                                 geometry
# 0      POLYGON ((-82.96438 38.04585, -82.96352 38.045...
# 1      GEOMETRYCOLLECTION (LINESTRING (-82.95661 38.0...
# 2      POLYGON ((-83.52908 37.35024, -83.52889 37.349...
# 3      POLYGON ((-84.37338 37.00735, -84.37334 37.007...
# 4      POLYGON ((-84.14509 36.91530, -84.14500 36.914...
# ...                                                  ...
# 12601  POLYGON ((-82.43439 37.45060, -82.43382 37.450...
# 12602  POLYGON ((-83.26042 37.14537, -83.26032 37.144...
# 12603  MULTIPOLYGON (((-84.00080 36.74794, -84.00077 ...
# 12604  MULTIPOLYGON (((-83.95358 36.79714, -83.95352 ...
# 12605  POLYGON ((-83.05177 36.85208, -83.05165 36.852...
#
# [12606 rows x 19 columns]

# %%
ky_mines['state'] = 'Kentucky'
tn_mines['state'] = 'Tennessee'
va_mines['state'] = 'Virginia'
wv_mines['state'] = 'West Virginia'

# %%
ky_mines[ky_mines['REGION_DES'].str.contains('PRESTONSBURG', na = False)]
# Out:
#                          id  ACT_INAC   Calc_Acres  \
# 0      00000000000000001111  Released   294.302954
# 1      00000000000000001112  Released   305.739886
# 5      000000000000000020c7  Released     2.799211
# 14     000000000000000003af  Released    10.959218
# 15     000000000000000014f0  Released    27.882968
# ...                     ...       ...          ...
# 12584  00000000000000000ac0  Released     4.760898
# 12586  00000000000000000e7f  Released   331.595984
# 12591  00000000000000000a7f  Released     1.939636
# 12598  00000000000000000994  Released  1110.850956
# 12599  000000000000000020da  Released    32.730356
#
#                            Contact       DATE_ISS FeatCLS MINE_STATU  \
# 0      KY Division of Mine Permits  1141718400000      SF         FF
# 1      KY Division of Mine Permits  1141718400000      SF         FF
# 5      KY Division of Mine Permits   388137600000      SF         FF
# 14     KY Division of Mine Permits   248601600000      SF         FF
# 15     KY Division of Mine Permits   470649600000      SF         FF
# ...                            ...            ...     ...        ...
# 12584  KY Division of Mine Permits  1363590000000      SF         VF
# 12586  KY Division of Mine Permits   926319600000      SF         VF
# 12591  KY Division of Mine Permits   845881200000      SF         VF
# 12598  KY Division of Mine Permits   815990400000      SF         VF
# 12599  KY Division of Mine Permits   316944000000      SF         XX
#
#       National_I ORIG_PERM                                           PERM_ACT  \
# 0      KY8640180   8640180  SU      03/07/2013  AM   1  05/12/2011  RN   1...
# 1      KY8640180   8640180  SU      03/07/2013  AM   1  05/12/2011  RN   1...
# 5      KY0320080   0320080                                 NW      04/20/1982
# 14     KY643677X   643677X                                 NW      11/17/1977
# 15     KY8800010   8800010                                 NW      11/30/1984
# ...          ...       ...                                                ...
# 12584  KY8365578   8365578  MT   1  04/06/2015  MI   2  04/09/2014  MI   1...
# 12586  KY8600369   8600369  MT   1  07/19/2002  MI   1  02/21/2000  NW    ...
# 12591  KY8365352   8365214  MTS   1  07/20/2001  MT   2  09/22/2000  RN   ...
# 12598  KY8360261   8360227  MI   8  01/23/2003  MI   7  06/14/2001  MT   2...
# 12599  KY0360017   0360017                                 RV      01/17/1980
#
#                            PER_NAME   PER_TYPE PermitNo     QUAD_DESC  \
# 0                  B & C ENERGY INC  PERMANENT  8640180         MAZIE
# 1                  B & C ENERGY INC  PERMANENT  8640180         MAZIE
# 5                     HERBERT WELLS    INTERIM  0320080          AULT
# 14            HERMITAGE COAL CO INC    PRE LAW  643677X          INEZ
# 15     TWIN STAR CONTRACTING CO INC  PERMANENT  8800010          INEZ
# ...                             ...        ...      ...           ...
# 12584     HONAKER COAL COMPANY, LTD  PERMANENT  8365578        HAROLD
# 12586           LODESTAR ENERGY INC  PERMANENT  8600369       HINDMAN
# 12591           LODESTAR ENERGY INC  PERMANENT  8365352      MCDOWELL
# 12598           LODESTAR ENERGY INC  PERMANENT  8360261  PRESTONSBURG
# 12599       SUPERIOR ELKHORN MINING    INTERIM  0360017        MARTIN
#
#          REGION_DES    Shape_Leng       Source Type_Flag  \
# 0      PRESTONSBURG  53267.493940         CHIA      TRNS
# 1      PRESTONSBURG  92560.008796        KYDMP      TRNS
# 5      PRESTONSBURG   3544.765063  KGS Project     INACT
# 14     PRESTONSBURG   5856.639354  KGS Project     INACT
# 15     PRESTONSBURG  16921.923911  KGS Project     INACT
# ...             ...           ...          ...       ...
# 12584  PRESTONSBURG   2671.732765         CHIA     INACT
# 12586  PRESTONSBURG  52647.491645  KGS Project     INACT
# 12591  PRESTONSBURG   1868.448097  KGS Project     INACT
# 12598  PRESTONSBURG  75297.917578  KGS Project     INACT
# 12599  PRESTONSBURG  20218.467497  KGS Project     INACT
#
#                                                 geometry     state
# 0      POLYGON ((-82.96438 38.04585, -82.96352 38.045...  Kentucky
# 1      GEOMETRYCOLLECTION (LINESTRING (-82.95661 38.0...  Kentucky
# 5      MULTIPOLYGON (((-83.19239 38.20341, -83.19215 ...  Kentucky
# 14     POLYGON ((-82.57781 37.83145, -82.57774 37.831...  Kentucky
# 15     MULTIPOLYGON (((-82.60824 37.76971, -82.60819 ...  Kentucky
# ...                                                  ...       ...
# 12584  POLYGON ((-82.65933 37.57050, -82.65883 37.569...  Kentucky
# 12586  POLYGON ((-82.89510 37.30441, -82.89481 37.304...  Kentucky
# 12591  MULTIPOLYGON (((-82.68270 37.47165, -82.68226 ...  Kentucky
# 12598  MULTIPOLYGON (((-82.73495 37.69519, -82.73478 ...  Kentucky
# 12599  MULTIPOLYGON (((-82.77597 37.61881, -82.77600 ...  Kentucky
#
# [3479 rows x 20 columns]

# %%
ky_mines
# Out:
#                          id  ACT_INAC  Calc_Acres  \
# 0      00000000000000001111  Released  294.302954
# 1      00000000000000001112  Released  305.739886
# 2      00000000000000001f4d  Released    4.822285
# 3      00000000000000002b96  Released    6.335894
# 4      00000000000000001d20  Released    2.864151
# ...                     ...       ...         ...
# 12601  0000000000000000025a  Released    1.112072
# 12602  00000000000000002e38  Released    4.185860
# 12603  00000000000000000472  Released   56.660359
# 12604  0000000000000000308a  Released   14.972560
# 12605  000000000000000004fc  Released   35.631015
#
#                            Contact       DATE_ISS FeatCLS MINE_STATU  \
# 0      KY Division of Mine Permits  1141718400000      SF         FF
# 1      KY Division of Mine Permits  1141718400000      SF         FF
# 2      KY Division of Mine Permits   374486400000      SF         FF
# 3      KY Division of Mine Permits   322732800000      SF         FF
# 4      KY Division of Mine Permits   455871600000      SF         FF
# ...                            ...            ...     ...        ...
# 12601  KY Division of Mine Permits   225619200000      SF         XX
# 12602  KY Division of Mine Permits   278582400000      SF         XX
# 12603  KY Division of Mine Permits   255254400000      SF         XX
# 12604  KY Division of Mine Permits   166863600000      SF         XX
# 12605  KY Division of Mine Permits   262598400000      SF         XX
#
#       National_I ORIG_PERM                                           PERM_ACT  \
# 0      KY8640180   8640180  SU      03/07/2013  AM   1  05/12/2011  RN   1...
# 1      KY8640180   8640180  SU      03/07/2013  AM   1  05/12/2011  RN   1...
# 2      KY0130119   0130119                                 NW      11/13/1981
# 3      KY1005000   1005000             RV      01/13/1981  NW      03/24/1980
# 4      KY9180010   9180010                                 NW      06/12/1984
# ...          ...       ...                                                ...
# 12601  KY545876X   545876X                                 NW      02/24/1977
# 12602  KY2660005   2660005                                 NW      10/30/1978
# 12603  KY686977X   686977X                                 NW      02/02/1978
# 12604  KY388574X   388574X             AM      07/14/1975  NW      04/16/1975
# 12605  KY710477X   710477X                                 NW      04/28/1978
#
#                             PER_NAME   PER_TYPE PermitNo       QUAD_DESC  \
# 0                   B & C ENERGY INC  PERMANENT  8640180           MAZIE
# 1                   B & C ENERGY INC  PERMANENT  8640180           MAZIE
# 2      TENKILLER MINING SERVICES INC    INTERIM  0130119
# 3               LAUREL RIVER COAL CO    INTERIM  1005000             ANO
# 4                 RIDNER COAL CO INC  PERMANENT  9180010             VOX
# ...                              ...        ...      ...             ...
# 12601             B J & C COAL SALES    PRE LAW  545876X         MILLARD
# 12602             FALCON COAL CO INC    INTERIM  2660005      HYDEN EAST
# 12603               CAL GLO COAL INC    PRE LAW  686977X    BARBOURVILLE
# 12604         KY PACIFIC MINING CORP    PRE LAW  388574X    BARBOURVILLE
# 12605        T & T DARBY COAL CO INC    PRE LAW  710477X  PENNINGTON GAP
#
#          REGION_DES    Shape_Leng       Source Type_Flag  \
# 0      PRESTONSBURG  53267.493940         CHIA      TRNS
# 1      PRESTONSBURG  92560.008796        KYDMP      TRNS
# 2            LONDON   1820.653854  KGS Project     INACT
# 3            LONDON   3259.238489  KGS Project     INACT
# 4       MIDDLESBORO   1867.456008  KGS Project     INACT
# ...             ...           ...          ...       ...
# 12601     PIKEVILLE   2501.756117  KGS Project     INACT
# 12602        LONDON   1713.922701  KGS Project     INACT
# 12603   MIDDLESBORO  16743.038634  KGS Project     INACT
# 12604   MIDDLESBORO   7858.160818  KGS Project     INACT
# 12605   MIDDLESBORO  77683.903613  KGS Project     INACT
#
#                                                 geometry     state
# 0      POLYGON ((-82.96438 38.04585, -82.96352 38.045...  Kentucky
# 1      GEOMETRYCOLLECTION (LINESTRING (-82.95661 38.0...  Kentucky
# 2      POLYGON ((-83.52908 37.35024, -83.52889 37.349...  Kentucky
# 3      POLYGON ((-84.37338 37.00735, -84.37334 37.007...  Kentucky
# 4      POLYGON ((-84.14509 36.91530, -84.14500 36.914...  Kentucky
# ...                                                  ...       ...
# 12601  POLYGON ((-82.43439 37.45060, -82.43382 37.450...  Kentucky
# 12602  POLYGON ((-83.26042 37.14537, -83.26032 37.144...  Kentucky
# 12603  MULTIPOLYGON (((-84.00080 36.74794, -84.00077 ...  Kentucky
# 12604  MULTIPOLYGON (((-83.95358 36.79714, -83.95352 ...  Kentucky
# 12605  POLYGON ((-83.05177 36.85208, -83.05165 36.852...  Kentucky
#
# [12606 rows x 20 columns]

# %%
#sources from https://www.msha.gov/data-and-reports/mine-data-retrieval-system
import csv
csv.register_dialect('piper', delimiter='|', quoting=csv.QUOTE_NONE)

#CoalDustSamples = pd.read_csv("/content/CoalDustSamples 2.txt", sep="|", encoding = "ISO-8859-1")
Mines_Address = pd.read_csv("/content/AddressOfRecord 2.txt", sep="|", encoding = "ISO-8859-1")
Ky = Mines_Address[Mines_Address['STATE'].str.contains('Kentucky', na = False)]
Ky[Ky['CITY'].str.contains('PRESTONSBURG', na = False)]

Mines = pd.read_csv("/content/Mines.txt", sep="|", encoding = "ISO-8859-1")
Mines[Mines['CURRENT_MINE_NAME'].str.contains('Brierfield Quarry', na = False)]
# Out:
#    MINE_ID  CURRENT_MINE_NAME COAL_METAL_IND CURRENT_MINE_TYPE  \
# 1   100004  Brierfield Quarry              M           Surface
#
#   CURRENT_MINE_STATUS CURRENT_STATUS_DT CURRENT_CONTROLLER_ID  \
# 1              Active        03/04/2003               0041044
#
#   CURRENT_CONTROLLER_NAME CURRENT_OPERATOR_ID  \
# 1            Lhoist Group              L13586
#
#                   CURRENT_OPERATOR_NAME  ... NO_NONPRODUCING_PITS  \
# 1  Lhoist North America of Alabama, LLC  ...                  NaN
#
#    NO_TAILING_PONDS  PILLAR_RECOVERY_USED HIGHWALL_MINER_USED  MULTIPLE_PITS  \
# 1               0.0                     N                   N              N
#
#   MINERS_REP_IND SAFETY_COMMITTEE_IND MILES_FROM_OFFICE  \
# 1              N                    N                35
#
#                                   DIRECTIONS_TO_MINE NEAREST_TOWN
# 1  I-65 SOUTH EXIT US 31 TO CALERA, TURN RIGHT ON...   Brierfield
#
# [1 rows x 59 columns]

# %%
#ky_mines.merge(Mines, left_on='PermitNo', right_on='MINE_ID', how='inner')

# %%
pip install git+https://github.com/giswqs/geemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/giswqs/geemap
#   Cloning https://github.com/giswqs/geemap to /tmp/pip-req-build-uqkx18b6
#   Running command git clone --filter=blob:none --quiet https://github.com/giswqs/geemap /tmp/pip-req-build-uqkx18b6
#   Resolved https://github.com/giswqs/geemap to commit a133a6d8e3b00aadba5bf8e6096b42d666c8f240
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: bqplot in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (0.12.39)
# Collecting colour (from geemap==0.22.1)
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: earthengine-api>=0.1.347 in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (0.1.350)
# Collecting eerepr>=0.0.4 (from geemap==0.22.1)
#   Downloading eerepr-0.0.4-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: folium>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (0.14.0)
# Collecting geocoder (from geemap==0.22.1)
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 4.4 MB/s eta 0:00:00
# Collecting ipyevents (from geemap==0.22.1)
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 14.0 MB/s eta 0:00:00
# Collecting ipyfilechooser>=0.6.0 (from geemap==0.22.1)
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (0.17.3)
# Collecting ipytree (from geemap==0.22.1)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (1.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (5.13.1)
# Collecting pyperclip (from geemap==0.22.1)
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyshp>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from geemap==0.22.1) (2.3.1)
# Collecting python-box (from geemap==0.22.1)
#   Downloading python_box-7.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 40.0 MB/s eta 0:00:00
# Collecting scooby (from geemap==0.22.1)
#   Downloading scooby-0.7.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.347->geemap==0.22.1) (2.8.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.347->geemap==0.22.1) (2.84.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.347->geemap==0.22.1) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.347->geemap==0.22.1) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.347->geemap==0.22.1) (0.21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.347->geemap==0.22.1) (2.27.1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium>=0.13.0->geemap==0.22.1) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium>=0.13.0->geemap==0.22.1) (3.1.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from ipyfilechooser>=0.6.0->geemap==0.22.1) (7.7.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet>=0.17.0->geemap==0.22.1) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet>=0.17.0->geemap==0.22.1) (2023.5.0)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from bqplot->geemap==0.22.1) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->geemap==0.22.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->geemap==0.22.1) (2022.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geocoder->geemap==0.22.1) (8.1.3)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder->geemap==0.22.1) (0.18.3)
# Collecting ratelim (from geocoder->geemap==0.22.1)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from geocoder->geemap==0.22.1) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->geemap==0.22.1) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->geemap==0.22.1) (8.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.22.1) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.22.1) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.22.1) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.22.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.22.1) (4.9)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (3.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium>=0.13.0->geemap==0.22.1) (2.1.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap==0.22.1) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap==0.22.1) (2.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->earthengine-api>=0.1.347->geemap==0.22.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->earthengine-api>=0.1.347->geemap==0.22.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->earthengine-api>=0.1.347->geemap==0.22.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->earthengine-api>=0.1.347->geemap==0.22.1) (3.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ratelim->geocoder->geemap==0.22.1) (4.4.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.22.1) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap==0.22.1) (3.20.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.347->geemap==0.22.1) (1.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (6.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (4.8.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap==0.22.1) (0.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.8.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser>=0.6.0->geemap==0.22.1) (2.21)
# Building wheels for collected packages: geemap, pyperclip
#   Building wheel for geemap (setup.py) ... done
#   Created wheel for geemap: filename=geemap-0.22.1-py2.py3-none-any.whl size=2176875 sha256=bc9022542ee328e559a22b8c61a66d4a54478e7bbcf5c6f8f6343c6d1c8c8d1d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0ise23li/wheels/ea/45/c2/b3314e9d778164b28c1d2279eed01bd116ff286c87a00d0ba9
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11124 sha256=9b3230e382771a853c5cd9066e9fb1fd902621bca2e10d615fd24e8ae2165fa7
#   Stored in directory: /root/.cache/pip/wheels/04/24/fe/140a94a7f1036003ede94579e6b4227fe96c840c6f4dcbe307
# Successfully built geemap pyperclip
# Installing collected packages: pyperclip, colour, scooby, ratelim, python-box, geocoder, eerepr, ipytree, ipyfilechooser, ipyevents, geemap
#   Attempting uninstall: geemap
#     Found existing installation: geemap 0.6.4
#     Uninstalling geemap-0.6.4:
#       Successfully uninstalled geemap-0.6.4
# Successfully installed colour-0.1.5 eerepr-0.0.4 geemap-0.22.1 geocoder-1.38.1 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipytree-0.2.2 pyperclip-1.8.2 python-box-7.0.1 ratelim-0.1.6 scooby-0.7.2

# %%
import geemap.eefolium as emap
Map = emap.Map(center=[40,-100], zoom=4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-355d1954f5b4> in <cell line: 1>()
# ----> 1 import geemap.eefolium as emap
#       2 Map = emap.Map(center=[40,-100], zoom=4)
#
# ModuleNotFoundError: No module named 'geemap.eefolium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install PyCRS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyCRS
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: PyCRS
#   Building wheel for PyCRS (setup.py) ... done
#   Created wheel for PyCRS: filename=PyCRS-1.0.2-py3-none-any.whl size=32686 sha256=2eb0be0ef826cf3ca2cc7bc7491d312c0bd894a6fa8187f284c26263785e6206
#   Stored in directory: /root/.cache/pip/wheels/47/1d/70/7a5bdf33347e7c75e95b06b1fa38f076a59a9506653cc24aff
# Successfully built PyCRS
# Installing collected packages: PyCRS
# Successfully installed PyCRS-1.0.2

# %%
#https://pypi.org/project/geemap/0.6.4/

import geemap

ee_object = geemap.geojson_to_ee('/content/TN_Released_mines.geojson')

#Map.addLayer(ee_object, {}, 'Layer name')

# %%
ee_object
# Out:
# /usr/local/lib/python3.10/dist-packages/eerepr/repr.py:57: UserWarning: Getting info failed with: 'GeometryConstructors.MultiGeometry: Geometry coordinate projection requires non-zero maxError.'. Falling back to string repr.
#   warn(f"Getting info failed with: '{e}'. Falling back to string repr.")
# <pre>&lt;ee.featurecollection.FeatureCollection object at 0x7f86bdb87130&gt;</pre>
